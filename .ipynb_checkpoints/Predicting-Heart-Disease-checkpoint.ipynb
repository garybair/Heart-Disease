# %% [markdown]
# # Data Mining Clinal Healthcare Data to Predict Heart Failure
#
# ### Context
#
# Cardiovascular diseases (CVD's) are the number one cause of death globally taking an estimated 17.9 million lives each year. Four out of five CVD deaths can be attributed to heart attacks and strokes, with one-third of these deaths occur prematurely in individuals under 70 years old. Given that heart failure is known to correlate with common clinical features collected during routine check-ups, machine learning offers a cost-efficient way to screen individuals do determine if their relative risk level.
#
# Authors:
# - Gary Bair
# - George Garcia
# - Luis Perez
#
# ### Package Requirements

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import sklearn
import xgboost as xgb
import graphviz
import os
import random
import imblearn
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeClassifier , export_graphviz
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn import metrics
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_iris
from sklearn import tree
from collections import Counter
from imblearn.over_sampling import SMOTE
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder, OrdinalEncoder, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.decomposition import PCA
import multiprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import Binarizer
from sklearn.preprocessing import OrdinalEncoder
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from collections import Counter
from imblearn.over_sampling import SMOTE
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, fbeta_score, roc_curve, roc_auc_score, confusion_matrix
from scipy.stats import loguniform

# %% [markdown]
# # Data Importing and Pre-processing
#
# ## Dataset Description
#
# This dataset was created by combining datasets already available independently but not previously combined in the UCI Machine Learning Repository. In this dataset, 5 heart datasets are combined over 11 common features which makes it the largest heart disease dataset available so far for research purposes. The five datasets used for its curation are:
#
# - Cleveland: 303 observations
# - Hungarian: 294 observations
# - Switzerland: 123 observations
# - Long Beach VA: 200 observations
# - Stalog (Heart) Data Set: 270 observations
#
# Total: 1190 observations <br />
# Duplicated: 272 observations <br />
#
# Final dataset: 918 observations <br />
#
# Origin: Kaggle <br />
# File Type: CSV <br />
# File Size: 35.1 kB <br />
# Modeling Problem: Classification <br />
# Missing Values: No <br />
#
# The individual datasets used to construct the dataset used in this analysis can be referenced using the index of heart disease datasets from UCI Machine Learning Repository which can be found at the following link: https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/
#
# ## Attribute Information:
# 1. Age: age of the patient [years]
# 2. Sex: sex of the patient [M: Male, F: Female]
# 3. ChestPainType: chest pain type [TA: Typical Angina, ATA: Atypical Angina, NAP: Non-Anginal Pain, ASY: Asymptomatic]
# 4. RestingBP: resting blood pressure [mm Hg]
# 5. Cholesterol: serum cholesterol [mm/dl]
# 6. FastingBS: fasting blood sugar [1: if FastingBS > 120 mg/dl, 0: otherwise]
# 7. RestingECG: resting electrocardiogram results [Normal: Normal, ST: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV), LVH: showing probable or definite left ventricular hypertrophy by Estes' criteria]
# 8. MaxHR: maximum heart rate achieved [Numeric value between 60 and 202]
# 9. ExerciseAngina: exercise-induced angina [Y: Yes, N: No]
# 10. Oldpeak: oldpeak = ST [Numeric value measured in depression]
# 11. ST_Slope: the slope of the peak exercise ST segment [Up: upsloping, Flat: flat, Down: downsloping]
# 12. HeartDisease: output class [1: heart disease, 0: Normal]
#
#
# ### Read Dataset and Display Info,

# %%
df= pd.read_csv('heart.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.nunique()
# Out:
# Age                50
# Sex                 2
# ChestPainType       4
# RestingBP          67
# Cholesterol       222
# FastingBS           2
# RestingECG          3
# MaxHR             119
# ExerciseAngina      2
# Oldpeak            53
# ST_Slope            3
# HeartDisease        2
# dtype: int64

# %% [markdown]
# ### Display Columns

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %% [markdown]
# ### Dataframe Dimensions

# %%
df.shape
# Out:
# (918, 12)

# %% [markdown]
# ### Missing Data

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %% [markdown]
# We observe that there are no missing values in this dataset thus data imputation will not be required.

# %% [markdown]
# ### Data Statistics

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %% [markdown]
# We note that all values exist within plausible ranges. Resting BP can be zero in cases of severe hypertension and FastingBS/HeartDisease are binary variables thus are admissible at this stage of analysis.

# %% [markdown]
# ### Data Transformation

# %%
cat_variables = ['Sex','ChestPainType','FastingBS','RestingECG','ExerciseAngina','ST_Slope']
num_variables = ['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak']

# %%
cat_dummies = pd.get_dummies(df[cat_variables])

# %%
def mm_normalize(df,col_list):
    temp_df = pd.DataFrame()
    for col in col_list:
        temp_df[col] = (df[col] - df[col].min()) / (df[col].max() - df[col].min())
    return temp_df

# %%
num_normed = mm_normalize(df, num_variables)

# %%
processed_df = pd.concat([num_normed, cat_dummies],axis = 1)

# %%
processed_df.head()
# Out:
#         Age  RestingBP  Cholesterol     MaxHR   Oldpeak  FastingBS  Sex_F  \
# 0  0.244898       0.70     0.479270  0.788732  0.295455          0      0
# 1  0.428571       0.80     0.298507  0.676056  0.409091          0      1
# 2  0.183673       0.65     0.469320  0.267606  0.295455          0      0
# 3  0.408163       0.69     0.354892  0.338028  0.465909          0      1
# 4  0.530612       0.75     0.323383  0.436620  0.295455          0      0
#
#    Sex_M  ChestPainType_ASY  ChestPainType_ATA  ChestPainType_NAP  \
# 0      1                  0                  1                  0
# 1      0                  0                  0                  1
# 2      1                  0                  1                  0
# 3      0                  1                  0                  0
# 4      1                  0                  0                  1
#
#    ChestPainType_TA  RestingECG_LVH  RestingECG_Normal  RestingECG_ST  \
# 0                 0               0                  1              0
# 1                 0               0                  1              0
# 2                 0               0                  0              1
# 3                 0               0                  1              0
# 4                 0               0                  1              0
#
#    ExerciseAngina_N  ExerciseAngina_Y  ST_Slope_Down  ST_Slope_Flat  \
# 0                 1                 0              0              0
# 1                 1                 0              0              1
# 2                 1                 0              0              0
# 3                 0                 1              0              1
# 4                 1                 0              0              0
#
#    ST_Slope_Up
# 0            1
# 1            0
# 2            1
# 3            0
# 4            1

# %% [markdown]
# # Data Analysis and Visualization

# %% [markdown]
# ## Identifying Variable Types
#
# ### Categorical Features:
# - Sex: sex of the patient [M: Male, F: Female] <br />
# - ChestPainType: chest pain type [TA: Typical Angina, ATA: Atypical Angina, NAP: Non-Anginal Pain, ASY: Asymptomatic] <br />
# - FastingBS: fasting blood sugar [1: if FastingBS > 120 mg/dl, 0: otherwise] <br />
# - RestingECG: resting electrocardiogram results [Normal: Normal, ST: having ST-T wave abnormality, LVH: showing probable or definite left ventricular hypertrophy] <br />
# - ExerciseAngina: exercise-induced angina [Y: Yes, N: No]<br />
# - ST_Slope: the slope of the peak exercise ST segment [Up: upsloping, Flat: flat, Down: downsloping]
# - HeartDisease: output class [1: heart disease, 0: Normal] <br />
#
# ### Numerical Features:
# - Age: age of the patient [years]
# - RestingBP: resting blood pressure [mm Hg]
# - Cholesterol: serum cholesterol [mm/dl]
# - MaxHR: maximum heart rate achieved [Numeric value between 60 and 202]
# - Oldpeak: oldpeak = ST [Numeric value measured in depression]

# %%
for col in cat_variables:
    crosstab = pd.crosstab(df[col], df['HeartDisease'])
    crosstab_norm = crosstab.div(crosstab.sum(1), axis = 0)
    fig, [ax1, ax2] = plt.subplots(nrows = 1, ncols= 2)
    fig.suptitle('Stacked Bar Graph of {}, with overlay of HeartDisease'.format(col))
    ax1.set_title('Raw')
    crosstab.plot(kind = 'bar', ax = ax1, stacked = True, figsize = (8,5), sort_columns = True)
    ax2.set_title('Normalized')
    crosstab_norm.plot(kind = 'bar', ax = ax2, stacked = True, figsize = (8,5), sort_columns = True)

# %%
print('HeartDisease split')
print(df.HeartDisease.value_counts(normalize = True))
print('\n')
for col in cat_variables:
    ct_1 = pd.crosstab(df['HeartDisease'], df[col])
    ct_2 = pd.crosstab(df['HeartDisease'], 
                       df[col],
                       normalize = 'columns')
    print('{} Values'.format(col))
    print(ct_1)
    print('\n')
    print('{} Percentages'.format(col))
    print(ct_2)
    print('\n')
# Out:
# HeartDisease split
# 1    0.553377
# 0    0.446623
# Name: HeartDisease, dtype: float64
#
#
# Sex Values
# Sex             F    M
# HeartDisease
# 0             143  267
# 1              50  458
#
#
# Sex Percentages
# Sex                  F         M
# HeartDisease
# 0             0.740933  0.368276
# 1             0.259067  0.631724
#
#
# ChestPainType Values
# ChestPainType  ASY  ATA  NAP  TA
# HeartDisease
# 0              104  149  131  26
# 1              392   24   72  20
#
#
# ChestPainType Percentages
# ChestPainType       ASY       ATA      NAP        TA
# HeartDisease
# 0              0.209677  0.861272  0.64532  0.565217
# 1              0.790323  0.138728  0.35468  0.434783
#
#
# FastingBS Values
# FastingBS       0    1
# HeartDisease
# 0             366   44
# 1             338  170
#
#
# FastingBS Percentages
# FastingBS            0         1
# HeartDisease
# 0             0.519886  0.205607
# 1             0.480114  0.794393
#
#
# RestingECG Values
# RestingECG    LVH  Normal   ST
# HeartDisease
# 0              82     267   61
# 1             106     285  117
#
#
# RestingECG Percentages
# RestingECG        LVH    Normal        ST
# HeartDisease
# 0             0.43617  0.483696  0.342697
# 1             0.56383  0.516304  0.657303
#
#
# ExerciseAngina Values
# ExerciseAngina    N    Y
# HeartDisease
# 0               355   55
# 1               192  316
#
#
# ExerciseAngina Percentages
# ExerciseAngina         N         Y
# HeartDisease
# 0               0.648995  0.148248
# 1               0.351005  0.851752
#
#
# ST_Slope Values
# ST_Slope      Down  Flat   Up
# HeartDisease
# 0               14    79  317
# 1               49   381   78
#
#
# ST_Slope Percentages
# ST_Slope          Down      Flat        Up
# HeartDisease
# 0             0.222222  0.171739  0.802532
# 1             0.777778  0.828261  0.197468

# %%
for col in num_variables:
    fig, [ax1, ax2] = plt.subplots(nrows = 1, ncols= 2)
    fig.suptitle('Histogram of {}, with overlay of HeartDisease'.format(col))
    ax1.set_title('Raw')
    ax2.set_title('Normalized')

    y = df[df.HeartDisease == 1][col]
    n = df[df.HeartDisease == 0][col]
    
    n, bins, patches = ax1.hist([y, n], bins = 10, stacked = True)
    n_table = np.column_stack((n[0], n[1]))
    n_sum = n_table.sum(axis=1)[:, None]
    n_norm = np.true_divide(n_table, n_sum)
    ourbins = np.column_stack((bins[0:10], bins[1:11]))
    
    ax2.bar(x = ourbins[:,0], 
       height = n_norm[:,1], 
       width = ourbins[:, 1] - ourbins[:, 0])
    ax2.bar(x = ourbins[:,0], 
       height = n_norm[:,1], 
       width = ourbins[:, 1] - ourbins[:, 0], 
       bottom = n_norm[:,0])
# Out:
# <ipython-input-16-4b89e19b704e>:13: RuntimeWarning: invalid value encountered in true_divide
#   n_norm = np.true_divide(n_table, n_sum)

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.skew()
# Out:
# Age            -0.195933
# RestingBP       0.179839
# Cholesterol    -0.610086
# FastingBS       1.264484
# MaxHR          -0.144359
# Oldpeak         1.022872
# HeartDisease   -0.215086
# dtype: float64

# %%
df.groupby('HeartDisease').mean()
# Out:
#                     Age   RestingBP  Cholesterol  FastingBS       MaxHR  \
# HeartDisease
# 0             50.551220  130.180488   227.121951   0.107317  148.151220
# 1             55.899606  134.185039   175.940945   0.334646  127.655512
#
#                Oldpeak
# HeartDisease
# 0             0.408049
# 1             1.274213

# %% [markdown]
# ## Bivariate Analysis

# %%
corr = df.corr()
corr
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %%
plt.figure(figsize = (14,7))
sns.heatmap(corr, 
            annot = True , 
            fmt = '.2f')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df, hue = 'HeartDisease')

# %% [markdown]
# # Data Analytics
#
# ### Data Partitioning and Balancing

# %%
y = df['HeartDisease']
y_names = ['Heart Disease','No Heart Disease']
y.head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# Name: HeartDisease, dtype: int64

# %%
X = processed_df
X_names =['Age',
          'RestingBP',
          'Cholesterol',
          'MaxHR',
          'Oldpeak',
          'FastingBS',
          'Female', 'Male',
          'ChestPainType_Asymptomatic','ChestPainType_ATA','ChestPainType_TA', 'ChestPainType_NAP',
          'RestingECG_LVH','RestingECG_Normal', 'RestingECG_ST',
          'ExerciseAngina_N','ExerciseAngina_Y',
          'ST_Slope_Down','ST_Slope_Flat','ST_Slope_Up']
X.head()
# Out:
#         Age  RestingBP  Cholesterol     MaxHR   Oldpeak  FastingBS  Sex_F  \
# 0  0.244898       0.70     0.479270  0.788732  0.295455          0      0
# 1  0.428571       0.80     0.298507  0.676056  0.409091          0      1
# 2  0.183673       0.65     0.469320  0.267606  0.295455          0      0
# 3  0.408163       0.69     0.354892  0.338028  0.465909          0      1
# 4  0.530612       0.75     0.323383  0.436620  0.295455          0      0
#
#    Sex_M  ChestPainType_ASY  ChestPainType_ATA  ChestPainType_NAP  \
# 0      1                  0                  1                  0
# 1      0                  0                  0                  1
# 2      1                  0                  1                  0
# 3      0                  1                  0                  0
# 4      1                  0                  0                  1
#
#    ChestPainType_TA  RestingECG_LVH  RestingECG_Normal  RestingECG_ST  \
# 0                 0               0                  1              0
# 1                 0               0                  1              0
# 2                 0               0                  0              1
# 3                 0               0                  1              0
# 4                 0               0                  1              0
#
#    ExerciseAngina_N  ExerciseAngina_Y  ST_Slope_Down  ST_Slope_Flat  \
# 0                 1                 0              0              0
# 1                 1                 0              0              1
# 2                 1                 0              0              0
# 3                 0                 1              0              1
# 4                 1                 0              0              0
#
#    ST_Slope_Up
# 0            1
# 1            0
# 2            1
# 3            0
# 4            1

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=0.3, 
                                                    random_state=0)

# %% [markdown]
# ### Resampling

# %%
print('Target Feature Counts')
print(y_train.value_counts())

print('Target Feature Distribution')
print(y_train.value_counts(normalize = True))
# Out:
# Target Feature Counts
# 1    345
# 0    297
# Name: HeartDisease, dtype: int64
# Target Feature Distribution
# 1    0.537383
# 0    0.462617
# Name: HeartDisease, dtype: float64

# %% [markdown]
# The default distribution of HeartDisease is observed to be roughly a 54%/46% split.

# %%
over_sampler = SMOTE(k_neighbors=2)
X_train_reb, y_train_reb = over_sampler.fit_resample(X_train, y_train)

print('Target Feature Distribution after Rebalancing')
print(y_train_reb.value_counts(normalize = True))
# Out:
# Target Feature Distribution after Rebalancing
# 1    0.5
# 0    0.5
# Name: HeartDisease, dtype: float64

# %% [markdown]
# The training dataset now has a 50%/50% split. The test dataset is unmodified and will remain as such. Due to how SMOTE operates, we must recast y_train_reb to NumPy array.

# %% [markdown]
# ## Logistic Regression

# %%
lr_baseline = LogisticRegression(random_state=0).fit(X_train_reb, y_train_reb)
lr_baseline_y_pred = lr_baseline.predict(X_test)

# %%
ct_lr = pd.DataFrame()
ct_lr['Actual'] = y_test
ct_lr['lr_basline'] = lr_baseline_y_pred

lr_confusion = pd.crosstab(ct_lr['Actual'],
                           ct_lr['lr_basline'])
lr_confusion
# Out:
# lr_basline   0    1
# Actual
# 0           87   26
# 1           21  142

# %%
data = [accuracy_score(y_test, lr_baseline_y_pred, normalize=True), 
        precision_score(y_test, lr_baseline_y_pred),
        recall_score(y_test, lr_baseline_y_pred),
        fbeta_score(y_test, lr_baseline_y_pred, beta=1),
        fbeta_score(y_test, lr_baseline_y_pred, beta=2),
        fbeta_score(y_test, lr_baseline_y_pred, beta=0.5),
        roc_auc_score(y_test, lr_baseline_y_pred)
       ]


test_names = ['Accuracy',
              'Precision',
              'Recall',
              'F1',
              'F2',
              'F0.5',
              'AUC ROC'
             ]

Model_Evaluation_Table = pd.DataFrame(data, index = test_names, columns = ['LR_Baseline'])

# %%
lr_space = dict()
lr_space['C'] = np.logspace(-3,3,7)
lr_space['penalty'] = ['none', 'l1', 'l2', 'elasticnet']
lr_space['l1_ratio'] = np.linspace(0, 1, 10)

# %%
lr = LogisticRegression(random_state=0, solver = 'saga')
lr_gs = GridSearchCV(lr, 
                     lr_space, 
                     scoring = 'accuracy', 
                     n_jobs = -1)
lr_gs.fit(X_train_reb, y_train_reb)
print('Best Score: %s' % lr_gs.best_score_)
print('Best Hyperparameters: %s' % lr_gs.best_params_)
# Out:
# Best Score: 0.8768115942028987
# Best Hyperparameters: {'C': 0.1, 'l1_ratio': 0.0, 'penalty': 'l2'}
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1476: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(

# %%
lr_v1_y_pred = lr_gs.predict(X_test)

# %%
ct_lr['lr_v1'] = lr_v1_y_pred

lr_confusion = pd.crosstab(ct_lr['Actual'],
                           ct_lr['lr_v1'])
lr_confusion
# Out:
# lr_v1    0    1
# Actual
# 0       85   28
# 1       21  142

# %%
data = [accuracy_score(y_test, lr_v1_y_pred, normalize=True), 
        precision_score(y_test, lr_v1_y_pred),
        recall_score(y_test, lr_v1_y_pred),
        fbeta_score(y_test, lr_v1_y_pred, beta=1),
        fbeta_score(y_test, lr_v1_y_pred, beta=2),
        fbeta_score(y_test, lr_v1_y_pred, beta=0.5),
        roc_auc_score(y_test, lr_v1_y_pred)
       ]

Model_Evaluation_Table['LR_V1'] = data

# %% [markdown]
# ## CART Decision Tree

# %%
cart_baseline = DecisionTreeClassifier(random_state = 0).fit(X_train_reb, y_train_reb)
cart_baseline_y_pred = cart_baseline.predict(X_test)

# %%
plt.figure(figsize=(20,10))
tree.plot_tree(cart_baseline, 
               filled = True,
               rounded =True, 
               class_names = y_names,
               feature_names = X_names)
# Out:
# [Text(594.284090909091, 524.1857142857143, 'ST_Slope_Up <= 0.5\ngini = 0.5\nsamples = 690\nvalue = [345, 345]\nclass = Heart Disease'),
#  Text(296.6136363636364, 485.3571428571429, 'ChestPainType_Asymptomatic <= 0.5\ngini = 0.301\nsamples = 368\nvalue = [68, 300]\nclass = No Heart Disease'),
#  Text(121.88636363636364, 446.52857142857147, 'Male <= 0.5\ngini = 0.477\nsamples = 117\nvalue = [46, 71]\nclass = No Heart Disease'),
#  Text(56.36363636363637, 407.70000000000005, 'Oldpeak <= 0.301\ngini = 0.375\nsamples = 24\nvalue = [18, 6]\nclass = Heart Disease'),
#  Text(33.81818181818182, 368.8714285714286, 'RestingBP <= 0.673\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = No Heart Disease'),
#  Text(22.545454545454547, 330.0428571428572, 'Cholesterol <= 0.468\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Heart Disease'),
#  Text(11.272727272727273, 291.2142857142857, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Heart Disease'),
#  Text(33.81818181818182, 291.2142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = No Heart Disease'),
#  Text(45.09090909090909, 330.0428571428572, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = No Heart Disease'),
#  Text(78.9090909090909, 368.8714285714286, 'MaxHR <= 0.366\ngini = 0.198\nsamples = 18\nvalue = [16, 2]\nclass = Heart Disease'),
#  Text(67.63636363636364, 330.0428571428572, 'Age <= 0.602\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = No Heart Disease'),
#  Text(56.36363636363637, 291.2142857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Heart Disease'),
#  Text(78.9090909090909, 291.2142857142857, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = No Heart Disease'),
#  Text(90.18181818181819, 330.0428571428572, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]\nclass = Heart Disease'),
#  Text(187.4090909090909, 407.70000000000005, 'MaxHR <= 0.481\ngini = 0.421\nsamples = 93\nvalue = [28, 65]\nclass = No Heart Disease'),
#  Text(124.0, 368.8714285714286, 'ExerciseAngina_Y <= 0.5\ngini = 0.108\nsamples = 35\nvalue = [2, 33]\nclass = No Heart Disease'),
#  Text(112.72727272727273, 330.0428571428572, 'Cholesterol <= 0.094\ngini = 0.278\nsamples = 12\nvalue = [2, 10]\nclass = No Heart Disease'),
#  Text(101.45454545454547, 291.2142857142857, 'Oldpeak <= 0.335\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = No Heart Disease'),
#  Text(90.18181818181819, 252.3857142857143, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = No Heart Disease'),
#  Text(112.72727272727273, 252.3857142857143, 'FastingBS <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Heart Disease'),
#  Text(101.45454545454547, 213.55714285714288, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Heart Disease'),
#  Text(124.0, 213.55714285714288, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = No Heart Disease'),
#  Text(124.0, 291.2142857142857, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = No Heart Disease'),
#  Text(135.27272727272728, 330.0428571428572, 'gini = 0.0\nsamples = 23\nvalue = [0, 23]\nclass = No Heart Disease'),
#  Text(250.81818181818184, 368.8714285714286, 'Cholesterol <= 0.418\ngini = 0.495\nsamples = 58\nvalue = [26, 32]\nclass = No Heart Disease'),
#  Text(208.54545454545456, 330.0428571428572, 'Oldpeak <= 0.517\ngini = 0.485\nsamples = 41\nvalue = [24, 17]\nclass = Heart Disease'),
#  Text(180.36363636363637, 291.2142857142857, 'Oldpeak <= 0.301\ngini = 0.4\nsamples = 29\nvalue = [21, 8]\nclass = Heart Disease'),
#  Text(157.8181818181818, 252.3857142857143, 'ChestPainType_ATA <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = No Heart Disease'),
#  Text(146.54545454545456, 213.55714285714288, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = No Heart Disease'),
#  Text(169.0909090909091, 213.55714285714288, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Heart Disease'),
#  Text(202.90909090909093, 252.3857142857143, 'RestingBP <= 0.262\ngini = 0.287\nsamples = 23\nvalue = [19, 4]\nclass = Heart Disease'),
#  Text(191.63636363636365, 213.55714285714288, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = No Heart Disease'),
#  Text(214.1818181818182, 213.55714285714288, 'ChestPainType_TA <= 0.5\ngini = 0.236\nsamples = 22\nvalue = [19, 3]\nclass = Heart Disease'),
#  Text(202.90909090909093, 174.72857142857146, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]\nclass = Heart Disease'),
#  Text(225.45454545454547, 174.72857142857146, 'Oldpeak <= 0.385\ngini = 0.397\nsamples = 11\nvalue = [8, 3]\nclass = Heart Disease'),
#  Text(202.90909090909093, 135.90000000000003, 'Age <= 0.602\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = No Heart Disease'),
#  Text(191.63636363636365, 97.07142857142861, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = No Heart Disease'),
#  Text(214.1818181818182, 97.07142857142861, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Heart Disease'),
#  Text(248.0, 135.90000000000003, 'Cholesterol <= 0.391\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = Heart Disease'),
#  Text(236.72727272727275, 97.07142857142861, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Heart Disease'),
#  Text(259.2727272727273, 97.07142857142861, 'Cholesterol <= 0.396\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Heart Disease'),
#  Text(248.0, 58.24285714285713, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = No Heart Disease'),
#  Text(270.54545454545456, 58.24285714285713, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Heart Disease'),
#  Text(236.72727272727275, 291.2142857142857, 'MaxHR <= 0.687\ngini = 0.375\nsamples = 12\nvalue = [3, 9]\nclass = No Heart Disease'),
#  Text(225.45454545454547, 252.3857142857143, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = No Heart Disease'),
#  Text(248.0, 252.3857142857143, 'RestingBP <= 0.61\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Heart Disease'),
#  Text(236.72727272727275, 213.55714285714288, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = No Heart Disease'),
#  Text(259.2727272727273, 213.55714285714288, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Heart Disease'),
#  Text(293.0909090909091, 330.0428571428572, 'MaxHR <= 0.842\ngini = 0.208\nsamples = 17\nvalue = [2, 15]\nclass = No Heart Disease'),
#  Text(281.8181818181818, 291.2142857142857, 'ST_Slope_Down <= 0.5\ngini = 0.117\nsamples = 16\nvalue = [1, 15]\nclass = No Heart Disease'),
#  Text(270.54545454545456, 252.3857142857143, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]\nclass = No Heart Disease'),
#  Text(293.0909090909091, 252.3857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Heart Disease'),
#  Text(304.3636363636364, 291.2142857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Heart Disease'),
#  Text(471.3409090909091, 446.52857142857147, 'RestingBP <= 0.43\ngini = 0.16\nsamples = 251\nvalue = [22, 229]\nclass = No Heart Disease'),
#  Text(460.06818181818187, 407.70000000000005, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Heart Disease'),
#  Text(482.6136363636364, 407.70000000000005, 'Male <= 0.5\ngini = 0.154\nsamples = 250\nvalue = [21, 229]\nclass = No Heart Disease'),
#  Text(360.72727272727275, 368.8714285714286, 'RestingBP <= 0.705\ngini = 0.332\nsamples = 38\nvalue = [8, 30]\nclass = No Heart Disease'),
#  Text(349.4545454545455, 330.0428571428572, 'Oldpeak <= 0.415\ngini = 0.454\nsamples = 23\nvalue = [8, 15]\nclass = No Heart Disease'),
#  Text(326.90909090909093, 291.2142857142857, 'MaxHR <= 0.655\ngini = 0.48\nsamples = 10\nvalue = [6, 4]\nclass = Heart Disease'),
#  Text(315.6363636363636, 252.3857142857143, 'Age <= 0.235\ngini = 0.375\nsamples = 8\nvalue = [6, 2]\nclass = Heart Disease'),
#  Text(304.3636363636364, 213.55714285714288, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = No Heart Disease'),
#  Text(326.90909090909093, 213.55714285714288, 'RestingBP <= 0.695\ngini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = Heart Disease'),
#  Text(315.6363636363636, 174.72857142857146, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = Heart Disease'),
#  Text(338.1818181818182, 174.72857142857146, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = No Heart Disease'),
#  Text(338.1818181818182, 252.3857142857143, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = No Heart Disease'),
#  Text(372.0, 291.2142857142857, 'Age <= 0.806\ngini = 0.26\nsamples = 13\nvalue = [2, 11]\nclass = No Heart Disease'),
#  Text(360.72727272727275, 252.3857142857143, 'RestingBP <= 0.695\ngini = 0.153\nsamples = 12\nvalue = [1, 11]\nclass = No Heart Disease'),
#  Text(349.4545454545455, 213.55714285714288, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]\nclass = No Heart Disease'),
#  Text(372.0, 213.55714285714288, 'MaxHR <= 0.694\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Heart Disease'),
#  Text(360.72727272727275, 174.72857142857146, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Heart Disease'),
#  Text(383.2727272727273, 174.72857142857146, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = No Heart Disease'),
#  Text(383.2727272727273, 252.3857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Heart Disease'),
#  Text(372.0, 330.0428571428572, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]\nclass = No Heart Disease'),
#  Text(604.5, 368.8714285714286, 'MaxHR <= 0.658\ngini = 0.115\nsamples = 212\nvalue = [13, 199]\nclass = No Heart Disease'),
#  Text(566.4545454545455, 330.0428571428572, 'Age <= 0.949\ngini = 0.094\nsamples = 202\nvalue = [10, 192]\nclass = No Heart Disease'),
#  Text(524.1818181818182, 291.2142857142857, 'RestingBP <= 0.655\ngini = 0.086\nsamples = 200\nvalue = [9, 191]\nclass = No Heart Disease'),
#  Text(473.4545454545455, 252.3857142857143, 'RestingECG_ST <= 0.5\ngini = 0.154\nsamples = 95\nvalue = [8, 87]\nclass = No Heart Disease'),
#  Text(428.3636363636364, 213.55714285714288, 'Oldpeak <= 0.625\ngini = 0.076\nsamples = 76\nvalue = [3, 73]\nclass = No Heart Disease'),
#  Text(405.81818181818187, 174.72857142857146, 'Age <= 0.582\ngini = 0.056\nsamples = 70\nvalue = [2, 68]\nclass = No Heart Disease'),
#  Text(394.54545454545456, 135.90000000000003, 'gini = 0.0\nsamples = 42\nvalue = [0, 42]\nclass = No Heart Disease'),
#  Text(417.0909090909091, 135.90000000000003, 'Age <= 0.602\ngini = 0.133\nsamples = 28\nvalue = [2, 26]\nclass = No Heart Disease'),
#  Text(405.81818181818187, 97.07142857142861, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Heart Disease'),
#  Text(428.3636363636364, 97.07142857142861, 'Cholesterol <= 0.432\ngini = 0.071\nsamples = 27\nvalue = [1, 26]\nclass = No Heart Disease'),
#  Text(417.0909090909091, 58.24285714285713, 'gini = 0.0\nsamples = 21\nvalue = [0, 21]\nclass = No Heart Disease'),
#  Text(439.6363636363637, 58.24285714285713, 'Oldpeak <= 0.358\ngini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = No Heart Disease'),
#  Text(428.3636363636364, 19.41428571428571, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Heart Disease'),
#  Text(450.90909090909093, 19.41428571428571, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = No Heart Disease'),
#  Text(450.90909090909093, 174.72857142857146, 'MaxHR <= 0.602\ngini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = No Heart Disease'),
#  Text(439.6363636363637, 135.90000000000003, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = No Heart Disease'),
#  Text(462.1818181818182, 135.90000000000003, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Heart Disease'),
#  Text(518.5454545454546, 213.55714285714288, 'FastingBS <= 0.5\ngini = 0.388\nsamples = 19\nvalue = [5, 14]\nclass = No Heart Disease'),
#  Text(507.2727272727273, 174.72857142857146, 'Oldpeak <= 0.381\ngini = 0.473\nsamples = 13\nvalue = [5, 8]\nclass = No Heart Disease'),
#  Text(496.0, 135.90000000000003, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Heart Disease'),
#  Text(518.5454545454546, 135.90000000000003, 'RestingBP <= 0.635\ngini = 0.444\nsamples = 12\nvalue = [4, 8]\nclass = No Heart Disease'),
#  Text(496.0, 97.07142857142861, 'RestingBP <= 0.59\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Heart Disease'),
#  Text(484.72727272727275, 58.24285714285713, 'Age <= 0.429\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = No Heart Disease'),
#  Text(473.4545454545455, 19.41428571428571, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Heart Disease'),
#  Text(496.0, 19.41428571428571, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = No Heart Disease'),
#  Text(507.2727272727273, 58.24285714285713, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Heart Disease'),
#  Text(541.0909090909091, 97.07142857142861, 'MaxHR <= 0.268\ngini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = No Heart Disease'),
#  Text(529.8181818181819, 58.24285714285713, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Heart Disease'),
#  Text(552.3636363636364, 58.24285714285713, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = No Heart Disease'),
#  Text(529.8181818181819, 174.72857142857146, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = No Heart Disease'),
#  Text(574.909090909091, 252.3857142857143, 'Oldpeak <= 0.358\ngini = 0.019\nsamples = 105\nvalue = [1, 104]\nclass = No Heart Disease'),
#  Text(563.6363636363636, 213.55714285714288, 'Oldpeak <= 0.347\ngini = 0.117\nsamples = 16\nvalue = [1, 15]\nclass = No Heart Disease'),
#  Text(552.3636363636364, 174.72857142857146, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]\nclass = No Heart Disease'),
#  Text(574.909090909091, 174.72857142857146, 'RestingBP <= 0.75\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Heart Disease'),
#  Text(563.6363636363636, 135.90000000000003, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Heart Disease'),
#  Text(586.1818181818182, 135.90000000000003, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = No Heart Disease'),
#  Text(586.1818181818182, 213.55714285714288, 'gini = 0.0\nsamples = 89\nvalue = [0, 89]\nclass = No Heart Disease'),
#  Text(608.7272727272727, 291.2142857142857, 'ST_Slope_Flat <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Heart Disease'),
#  Text(597.4545454545455, 252.3857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Heart Disease'),
#  Text(620.0, 252.3857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = No Heart Disease'),
#  Text(642.5454545454546, 330.0428571428572, 'Cholesterol <= 0.363\ngini = 0.42\nsamples = 10\nvalue = [3, 7]\nclass = No Heart Disease'),
#  Text(631.2727272727273, 291.2142857142857, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = No Heart Disease'),
#  Text(653.8181818181819, 291.2142857142857, 'RestingECG_Normal <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Heart Disease'),
#  Text(642.5454545454546, 252.3857142857143, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = No Heart Disease'),
#  Text(665.0909090909091, 252.3857142857143, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Heart Disease'),
#  Text(891.9545454545455, 485.3571428571429, 'ChestPainType_Asymptomatic <= 0.5\ngini = 0.24\nsamples = 322\nvalue = [277, 45]\nclass = Heart Disease'),
#  Text(806.0, 446.52857142857147, 'Oldpeak <= 0.551\ngini = 0.086\nsamples = 223\nvalue = [213, 10]\nclass = Heart Disease'),
#  Text(794.7272727272727, 407.70000000000005, 'RestingBP <= 0.955\ngini = 0.07\nsamples = 221\nvalue = [213, 8]\nclass = Heart Disease'),
#  Text(783.4545454545455, 368.8714285714286, 'Age <= 0.898\ngini = 0.062\nsamples = 220\nvalue = [213, 7]\nclass = Heart Disease'),
#  Text(744.0, 330.0428571428572, 'Age <= 0.584\ngini = 0.045\nsamples = 216\nvalue = [211, 5]\nclass = Heart Disease'),
#  Text(698.909090909091, 291.2142857142857, 'RestingBP <= 0.545\ngini = 0.011\nsamples = 173\nvalue = [172, 1]\nclass = Heart Disease'),
#  Text(687.6363636363636, 252.3857142857143, 'RestingBP <= 0.535\ngini = 0.198\nsamples = 9\nvalue = [8, 1]\nclass = Heart Disease'),
#  Text(676.3636363636364, 213.55714285714288, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = Heart Disease'),
#  Text(698.909090909091, 213.55714285714288, 'Cholesterol <= 0.423\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Heart Disease'),
#  Text(687.6363636363636, 174.72857142857146, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = No Heart Disease'),
#  Text(710.1818181818182, 174.72857142857146, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Heart Disease'),
#  Text(710.1818181818182, 252.3857142857143, 'gini = 0.0\nsamples = 164\nvalue = [164, 0]\nclass = Heart Disease'),
#  Text(789.0909090909091, 291.2142857142857, 'Cholesterol <= 0.541\ngini = 0.169\nsamples = 43\nvalue = [39, 4]\nclass = Heart Disease'),
#  Text(766.5454545454546, 252.3857142857143, 'Age <= 0.634\ngini = 0.136\nsamples = 41\nvalue = [38, 3]\nclass = Heart Disease'),
#  Text(755.2727272727274, 213.55714285714288, 'ChestPainType_NAP <= 0.5\ngini = 0.32\nsamples = 15\nvalue = [12, 3]\nclass = Heart Disease'),
#  Text(732.7272727272727, 174.72857142857146, 'RestingBP <= 0.63\ngini = 0.153\nsamples = 12\nvalue = [11, 1]\nclass = Heart Disease'),
#  Text(721.4545454545455, 135.90000000000003, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = No Heart Disease'),
#  Text(744.0, 135.90000000000003, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]\nclass = Heart Disease'),
#  Text(777.8181818181819, 174.72857142857146, 'Cholesterol <= 0.461\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = No Heart Disease'),
#  Text(766.5454545454546, 135.90000000000003, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = No Heart Disease'),
#  Text(789.0909090909091, 135.90000000000003, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Heart Disease'),
#  Text(777.8181818181819, 213.55714285714288, 'gini = 0.0\nsamples = 26\nvalue = [26, 0]\nclass = Heart Disease'),
#  Text(811.6363636363637, 252.3857142857143, 'Male <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Heart Disease'),
#  Text(800.3636363636364, 213.55714285714288, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Heart Disease'),
#  Text(822.909090909091, 213.55714285714288, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = No Heart Disease'),
#  Text(822.909090909091, 330.0428571428572, 'RestingECG_ST <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Heart Disease'),
#  Text(811.6363636363637, 291.2142857142857, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Heart Disease'),
#  Text(834.1818181818182, 291.2142857142857, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = No Heart Disease'),
#  Text(806.0, 368.8714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = No Heart Disease'),
#  Text(817.2727272727274, 407.70000000000005, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = No Heart Disease'),
#  Text(977.909090909091, 446.52857142857147, 'ExerciseAngina_Y <= 0.5\ngini = 0.457\nsamples = 99\nvalue = [64, 35]\nclass = Heart Disease'),
#  Text(901.8181818181819, 407.70000000000005, 'Cholesterol <= 0.07\ngini = 0.337\nsamples = 70\nvalue = [55, 15]\nclass = Heart Disease'),
#  Text(879.2727272727274, 368.8714285714286, 'MaxHR <= 0.391\ngini = 0.346\nsamples = 9\nvalue = [2, 7]\nclass = No Heart Disease'),
#  Text(868.0, 330.0428571428572, 'Age <= 0.51\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Heart Disease'),
#  Text(856.7272727272727, 291.2142857142857, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Heart Disease'),
#  Text(879.2727272727274, 291.2142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = No Heart Disease'),
#  Text(890.5454545454546, 330.0428571428572, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = No Heart Disease'),
#  Text(924.3636363636364, 368.8714285714286, 'MaxHR <= 0.644\ngini = 0.228\nsamples = 61\nvalue = [53, 8]\nclass = Heart Disease'),
#  Text(913.0909090909091, 330.0428571428572, 'gini = 0.0\nsamples = 32\nvalue = [32, 0]\nclass = Heart Disease'),
#  Text(935.6363636363637, 330.0428571428572, 'MaxHR <= 0.694\ngini = 0.4\nsamples = 29\nvalue = [21, 8]\nclass = Heart Disease'),
#  Text(913.0909090909091, 291.2142857142857, 'RestingECG_Normal <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = No Heart Disease'),
#  Text(901.8181818181819, 252.3857142857143, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = No Heart Disease'),
#  Text(924.3636363636364, 252.3857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Heart Disease'),
#  Text(958.1818181818182, 291.2142857142857, 'RestingBP <= 0.755\ngini = 0.32\nsamples = 25\nvalue = [20, 5]\nclass = Heart Disease'),
#  Text(946.909090909091, 252.3857142857143, 'Cholesterol <= 0.361\ngini = 0.278\nsamples = 24\nvalue = [20, 4]\nclass = Heart Disease'),
#  Text(924.3636363636364, 213.55714285714288, 'Male <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]\nclass = Heart Disease'),
#  Text(913.0909090909091, 174.72857142857146, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Heart Disease'),
#  Text(935.6363636363637, 174.72857142857146, 'Age <= 0.316\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = No Heart Disease'),
#  Text(924.3636363636364, 135.90000000000003, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Heart Disease'),
#  Text(946.909090909091, 135.90000000000003, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = No Heart Disease'),
#  Text(969.4545454545455, 213.55714285714288, 'Age <= 0.602\ngini = 0.117\nsamples = 16\nvalue = [15, 1]\nclass = Heart Disease'),
#  Text(958.1818181818182, 174.72857142857146, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = Heart Disease'),
#  Text(980.7272727272727, 174.72857142857146, 'Cholesterol <= 0.473\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Heart Disease'),
#  Text(969.4545454545455, 135.90000000000003, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Heart Disease'),
#  Text(992.0, 135.90000000000003, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = No Heart Disease'),
#  Text(969.4545454545455, 252.3857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = No Heart Disease'),
#  Text(1054.0, 407.70000000000005, 'Oldpeak <= 0.375\ngini = 0.428\nsamples = 29\nvalue = [9, 20]\nclass = No Heart Disease'),
#  Text(1014.5454545454546, 368.8714285714286, 'RestingBP <= 0.683\ngini = 0.497\nsamples = 13\nvalue = [7, 6]\nclass = Heart Disease'),
#  Text(992.0, 330.0428571428572, 'MaxHR <= 0.722\ngini = 0.408\nsamples = 7\nvalue = [2, 5]\nclass = No Heart Disease'),
#  Text(980.7272727272727, 291.2142857142857, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = No Heart Disease'),
#  Text(1003.2727272727274, 291.2142857142857, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Heart Disease'),
#  Text(1037.0909090909092, 330.0428571428572, 'MaxHR <= 0.706\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Heart Disease'),
#  Text(1025.818181818182, 291.2142857142857, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Heart Disease'),
#  Text(1048.3636363636365, 291.2142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = No Heart Disease'),
#  Text(1093.4545454545455, 368.8714285714286, 'Cholesterol <= 0.127\ngini = 0.219\nsamples = 16\nvalue = [2, 14]\nclass = No Heart Disease'),
#  Text(1082.1818181818182, 330.0428571428572, 'FastingBS <= 0.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]\nclass = No Heart Disease'),
#  Text(1070.909090909091, 291.2142857142857, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Heart Disease'),
#  Text(1093.4545454545455, 291.2142857142857, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = No Heart Disease'),
#  Text(1104.7272727272727, 330.0428571428572, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = No Heart Disease')]

# %%
ct_cart = pd.DataFrame()
ct_cart['Actual'] = y_test
ct_cart['cart_baseline'] = cart_baseline_y_pred

cart_confusion = pd.crosstab(ct_cart['Actual'],
                             ct_cart['cart_baseline'])
cart_confusion
# Out:
# cart_baseline   0    1
# Actual
# 0              93   20
# 1              31  132

# %%
data = [accuracy_score(y_test, cart_baseline_y_pred, normalize=True), 
        precision_score(y_test, cart_baseline_y_pred),
        recall_score(y_test, cart_baseline_y_pred),
        fbeta_score(y_test, cart_baseline_y_pred, beta=1),
        fbeta_score(y_test, cart_baseline_y_pred, beta=2),
        fbeta_score(y_test, cart_baseline_y_pred, beta=0.5),
        roc_auc_score(y_test, cart_baseline_y_pred)
       ]

Model_Evaluation_Table['CART_Baseline'] = data

# %%
cart = DecisionTreeClassifier(random_state = 0, 
                              criterion = 'entropy', 
                              min_samples_leaf = 5)

cart_v1 = cart.fit(X_train_reb, y_train_reb)

cart_v1_y_pred = cart_v1.predict(X_test)

# %%
ct_cart['cart_v1'] = cart_v1_y_pred

cart_confusion = pd.crosstab(ct_cart['Actual'],
                             ct_cart['cart_v1'])
cart_confusion
# Out:
# cart_v1   0    1
# Actual
# 0        87   26
# 1        28  135

# %%
data = [accuracy_score(y_test, cart_v1_y_pred, normalize=True), 
        precision_score(y_test, cart_v1_y_pred),
        recall_score(y_test, cart_v1_y_pred),
        fbeta_score(y_test, cart_v1_y_pred, beta=1),
        fbeta_score(y_test, cart_v1_y_pred, beta=2),
        fbeta_score(y_test, cart_v1_y_pred, beta=0.5),
        roc_auc_score(y_test, cart_v1_y_pred)
       ]

Model_Evaluation_Table['CART_V1'] = data

# %% [markdown]
# ## XGBoost

# %%
xgb_baseline = xgb.XGBClassifier(random_state = 0, use_label_encoder = False).fit(X_train_reb, y_train_reb)
xgb_baseline_y_pred = xgb_baseline.predict(X_test)
# Out:
# [11:29:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
ct_xgb = pd.DataFrame()
ct_xgb['Actual'] = y_test
ct_xgb['xgb_baseline'] = xgb_baseline_y_pred

xgb_baseline_confusion = pd.crosstab(ct_xgb['Actual'],
                                     ct_xgb['xgb_baseline'])
xgb_baseline_confusion
# Out:
# xgb_baseline   0    1
# Actual
# 0             92   21
# 1             18  145

# %%
data = [accuracy_score(y_test, xgb_baseline_y_pred, normalize=True), 
        precision_score(y_test, xgb_baseline_y_pred),
        recall_score(y_test, xgb_baseline_y_pred),
        fbeta_score(y_test, xgb_baseline_y_pred, beta=1),
        fbeta_score(y_test, xgb_baseline_y_pred, beta=2),
        fbeta_score(y_test, xgb_baseline_y_pred, beta=0.5),
        roc_auc_score(y_test, xgb_baseline_y_pred)
       ]

Model_Evaluation_Table['XGB_Baseline'] = data

# %%
xgb_model = xgb.XGBClassifier(random_state = 0, 
                              use_label_encoder = False,
                              n_jobs=multiprocessing.cpu_count() // 2)
xgb_v1 = GridSearchCV(xgb_model,
                      {'max_depth': [2, 4, 6], 
                       'n_estimators': [50, 100, 200]}, 
                      verbose=1,
                      n_jobs=2)
xgb_v1_y_pred = xgb_v1.fit(X_train_reb, y_train_reb)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [11:29:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
xgb_v1_y_pred = xgb_v1.predict(X_test)

# %%
ct_xgb['xgb_v1'] = xgb_v1_y_pred

xgb_v1_confusion = pd.crosstab(ct_xgb['Actual'],
                               ct_xgb['xgb_v1'])
xgb_v1_confusion
# Out:
# xgb_v1   0    1
# Actual
# 0       92   21
# 1       19  144

# %%
data = [accuracy_score(y_test, xgb_v1_y_pred, normalize=True), 
        precision_score(y_test, xgb_v1_y_pred),
        recall_score(y_test, xgb_v1_y_pred),
        fbeta_score(y_test, xgb_v1_y_pred, beta=1),
        fbeta_score(y_test, xgb_v1_y_pred, beta=2),
        fbeta_score(y_test, xgb_v1_y_pred, beta=0.5),
        roc_auc_score(y_test, xgb_v1_y_pred)
       ]

Model_Evaluation_Table['XGB_V1'] = data

# %% [markdown]
# ## Model Evaluation

# %%
Model_Evaluation_Table
# Out:
#            LR_Baseline     LR_V1  CART_Baseline   CART_V1  XGB_Baseline  \
# Accuracy      0.829710  0.822464       0.815217  0.804348      0.858696
# Precision     0.845238  0.835294       0.868421  0.838509      0.873494
# Recall        0.871166  0.871166       0.809816  0.828221      0.889571
# F1            0.858006  0.852853       0.838095  0.833333      0.881459
# F2            0.865854  0.863747       0.820896  0.830258      0.886308
# F0.5          0.850299  0.842230       0.856031  0.836431      0.876663
# AUC ROC       0.820539  0.811689       0.816412  0.799066      0.851865
#
#              XGB_V1
# Accuracy   0.855072
# Precision  0.872727
# Recall     0.883436
# F1         0.878049
# F2         0.881273
# F0.5       0.874848
# AUC ROC    0.848797
